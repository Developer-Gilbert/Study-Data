# %% [markdown]
# # **1. 순차 탐색(Sequential search)**

# %% [markdown]
# - 탐색은 여러 데이터 중에서 원하는 데이터를 찾아내는 것을 의미
# - 데이터가 담겨있는 리스트를 앞에서부터 하나씩 비교해서 원하는 데이터를 찾는 방법

# %%
from random import *

rand_data_list = list()
for num in range(10):
  rand_data_list.append(randint(1, 100))

rand_data_list
# Out:
# [25, 43, 67, 57, 53, 88, 92, 58, 36, 67]

# %%
def sequencial(data_list, search_data):
  for i in range(len(data_list)):
    if data_list[i] == search_data:
      return search_data
  return -1

# %%
sequencial(rand_data_list, 36)
# Out:
# 36

# %% [markdown]
# # **2. 알고리즘 분석**

# %% [markdown]
# - 최악의 경우 리스트의 길이가 n일 때 n번 비교해야 함
# - 빅오 표기법으로 표현하면 O(n)
